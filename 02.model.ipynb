# %% [markdown]
# ## AI-Powered Size Chart Generator for Apparel Sellers
# ### After data cleaning

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

# Load the data
data = pd.read_csv('refined_cloth.csv')

# Data preprocessing
# Convert categorical variables into numerical ones
label_encoders = {}
for column in ['cup_size', 'hips', 'bra_size', 'category', 'length', 'fit', 'shoe_size', 'shoe_width']:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column].astype(str))
    label_encoders[column] = le

# Fill missing values with the most frequent value
imputer = SimpleImputer(strategy='most_frequent')
data_filled = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# Group data by category
category_groups = data_filled.groupby('category')

# Initialize the dictionary to store size charts
size_charts = {}

# Iterate over each category and create size charts
for category, group in category_groups:
    size_chart = {}

    for size in range(39):  # For sizes 0 to 38
        size_group = group[group['size'] == size]

        if size_group.empty:
            continue

        # Determine the number of clusters based on the number of samples
        n_clusters = min(5, len(size_group))

        if n_clusters < 1:
            continue

        # Clustering based on height and other features
        kmeans = KMeans(n_clusters=n_clusters, random_state=42)
        features = size_group[['height', 'cup_size', 'hips', 'bra_size', 'shoe_size', 'shoe_width']].values
        kmeans.fit(features)
        size_group['cluster'] = kmeans.labels_

        # For each cluster, calculate the average measurements and fit
        clusters = size_group.groupby('cluster').mean()
        confidence_scores = 1 - pairwise_distances_argmin_min(kmeans.cluster_centers_, features)[1] / len(features)

        # Build the size chart for this size
        size_chart[size] = {
            'height': clusters['height'].mean(),
            'cup_size': clusters['cup_size'].mean(),
            'hips': clusters['hips'].mean(),
            'bra_size': clusters['bra_size'].mean(),
            'shoe_size': clusters['shoe_size'].mean(),
            'shoe_width': clusters['shoe_width'].mean(),
            'confidence_score': np.mean(confidence_scores)
        }

    size_charts[category] = size_chart

# Function to adjust sizes based on fit and length feedback
def adjust_sizes_based_on_fit(group):
    for index, row in group.iterrows():
        if row['fit'] != 0 or row['length'] != 0:  # 0 indicates 'fit' and 'just right'
            if row['fit'] == 1 or row['length'] == 1:  # 1 indicates 'large' or 'slightly long'
                group.at[index, 'size'] = min(row['size'] + 1, 38)
            elif row['fit'] == 2 or row['length'] == 2:  # 2 indicates 'small' or 'slightly short'
                group.at[index, 'size'] = max(row['size'] - 1, 0)
    return group

# Adjust sizes based on fit
data_adjusted = category_groups.apply(adjust_sizes_based_on_fit)

# Output the size charts
for category, chart in size_charts.items():
    print(f"Size chart for {category}:")
    for size, measurements in chart.items():
        print(f"Size {size}: {measurements}")
    print("\n")
# Out:
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   size_group['cluster'] = kmeans.labels_
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# Size 17: {'height': 165.0649238095238, 'cup_size': 4.00047619047619, 'hips': 1.8795238095238098, 'bra_size': 5.824285714285714, 'shoe_size': 9.413809523809524, 'shoe_width': 0.8552380952380952, 'confidence_score': 0.9514900134442469}
# Size 18: {'height': 169.4329411764706, 'cup_size': 5.041911764705882, 'hips': 2.6716911764705884, 'bra_size': 5.894485294117647, 'shoe_size': 8.297426470588235, 'shoe_width': 0.8628676470588236, 'confidence_score': 0.9615796625571331}
# Size 20: {'height': 167.49694880570968, 'cup_size': 5.271826090507901, 'hips': 2.587083991778901, 'bra_size': 5.487545664698643, 'shoe_size': 10.677706055179842, 'shoe_width': 0.48866195113570887, 'confidence_score': 0.9993767450530793}
# Size 21: {'height': 168.86689696969697, 'cup_size': 5.391515151515152, 'hips': 2.835151515151515, 'bra_size': 5.611515151515151, 'shoe_size': 8.315151515151515, 'shoe_width': 0.47575757575757577, 'confidence_score': 0.9323547159302785}
# Size 24: {'height': 171.06900000000002, 'cup_size': 5.4, 'hips': 3.3, 'bra_size': 5.45, 'shoe_size': 8.683333333333334, 'shoe_width': 0.5166666666666666, 'confidence_score': 0.9385739509070842}
# Size 26: {'height': 152.70339108034258, 'cup_size': 6.24629252139279, 'hips': 3.1334015820757526, 'bra_size': 6.148319846636348, 'shoe_size': 10.918947932252303, 'shoe_width': 0.39845863704247997, 'confidence_score': 0.9992215621681646}
# Size 27: {'height': 167.87706666666665, 'cup_size': 5.546666666666667, 'hips': 3.746666666666667, 'bra_size': 6.32, 'shoe_size': 11.2, 'shoe_width': 0.6, 'confidence_score': 0.9320662886640434}
# Size 30: {'height': 171.34275555555558, 'cup_size': 4.622222222222222, 'hips': 3.4266666666666667, 'bra_size': 6.248888888888889, 'shoe_size': 7.777777777777777, 'shoe_width': 0.9777777777777779, 'confidence_score': 0.9601597815135149}
# Size 32: {'height': 153.7080201336883, 'cup_size': 5.481167008209121, 'hips': 3.4867374061266054, 'bra_size': 7.7777932713226265, 'shoe_size': 11.17724436423373, 'shoe_width': 0.38576434255130126, 'confidence_score': 0.9990101995418096}
# Size 33: {'height': 165.77733333333333, 'cup_size': 5.333333333333334, 'hips': 3.5333333333333328, 'bra_size': 8.733333333333334, 'shoe_size': 12.6, 'shoe_width': 1.4, 'confidence_score': 0.9707205194401016}
# Size 38: {'height': 169.19036018292377, 'cup_size': 5.242682808755686, 'hips': 3.4179104342886584, 'bra_size': 8.08645513377765, 'shoe_size': 10.947726228422402, 'shoe_width': 0.586756521574147, 'confidence_score': 0.997006243845977}
#
#
# Size chart for 3.0:
# Size 1: {'height': 160.3700641025641, 'cup_size': 2.6840659340659343, 'hips': 2.6314102564102564, 'bra_size': 4.318131868131869, 'shoe_size': 11.743589743589743, 'shoe_width': 0.3, 'confidence_score': 0.944774299709249}
# Size 4: {'height': 177.18268543285154, 'cup_size': 2.5777837288895005, 'hips': 2.3850740178397136, 'bra_size': 4.6999733180166015, 'shoe_size': 11.953847363180603, 'shoe_width': 0.2821068270048639, 'confidence_score': 0.9987281032000365}
# Size 8: {'height': 165.44935787911965, 'cup_size': 3.104836127450592, 'hips': 2.15006209182029, 'bra_size': 4.726082433547638, 'shoe_size': 12.493274351251234, 'shoe_width': 0.25035733636543406, 'confidence_score': 0.9986916730501709}
# Size 12: {'height': 183.5989197168829, 'cup_size': 5.918555394571622, 'hips': 2.1704469987228605, 'bra_size': 5.368695804758685, 'shoe_size': 8.482755647853011, 'shoe_width': 0.5637425222962749, 'confidence_score': 0.9988208334192364}
# Size 15: {'height': 168.23351759982128, 'cup_size': 4.8900891368475055, 'hips': 1.8706248681254576, 'bra_size': 4.8511846574571695, 'shoe_size': 10.50772067006748, 'shoe_width': 0.3919203829429847, 'confidence_score': 0.995240518675665}
# Size 20: {'height': 167.12904645928893, 'cup_size': 5.397634673618138, 'hips': 2.674658397297814, 'bra_size': 5.435523884806304, 'shoe_size': 10.457683542548455, 'shoe_width': 0.5201958220562444, 'confidence_score': 0.9960578933384534}
# Size 26: {'height': 169.28604556915306, 'cup_size': 5.2161950271950275, 'hips': 3.359253690753691, 'bra_size': 6.475323620823621, 'shoe_size': 8.369259324009324, 'shoe_width': 0.7303492618492619, 'confidence_score': 0.9961542544285027}
# Size 32: {'height': 170.50919115133235, 'cup_size': 5.450521809345339, 'hips': 3.4361357161357162, 'bra_size': 7.150900559135853, 'shoe_size': 10.933343998049882, 'shoe_width': 0.4031211054740466, 'confidence_score': 0.9925826502303586}
# Size 38: {'height': 168.1621111111111, 'cup_size': 6.442063492063492, 'hips': 3.5539682539682538, 'bra_size': 6.901587301587301, 'shoe_size': 8.742857142857144, 'shoe_width': 0.6857142857142857, 'confidence_score': 0.9176159356991473}
#
#
# Size chart for 4.0:
# Size 0: {'height': 160.02, 'cup_size': 2.5, 'hips': 2.25, 'bra_size': 1.5, 'shoe_size': 8.5, 'shoe_width': 0.5, 'confidence_score': 1.0}
# Size 1: {'height': 162.7807380952381, 'cup_size': 2.5710317460317462, 'hips': 2.471230158730159, 'bra_size': 2.936706349206349, 'shoe_size': 11.795238095238096, 'shoe_width': 0.3380952380952381, 'confidence_score': 0.9665731297028299}
# Size 3: {'height': 165.862, 'cup_size': 3.0, 'hips': 2.1, 'bra_size': 1.8, 'shoe_size': 11.0, 'shoe_width': 0.2, 'confidence_score': 0.9545039684270268}
# Size 4: {'height': 161.93125193050193, 'cup_size': 2.8197207207207207, 'hips': 2.3520830115830114, 'bra_size': 4.4349272844272845, 'shoe_size': 11.901438223938225, 'shoe_width': 0.3698301158301158, 'confidence_score': 0.9973217616588809}
# Size 5: {'height': 165.18466666666666, 'cup_size': 2.55, 'hips': 2.2333333333333334, 'bra_size': 4.316666666666666, 'shoe_size': 12.716666666666667, 'shoe_width': 0.5, 'confidence_score': 0.9215821649560392}
# Size 6: {'height': 158.75, 'cup_size': 2.0, 'hips': 3.0, 'bra_size': 7.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 7: {'height': 171.46693333333334, 'cup_size': 4.088888888888889, 'hips': 1.0355555555555553, 'bra_size': 4.546666666666667, 'shoe_size': 12.457777777777778, 'shoe_width': 0.1511111111111111, 'confidence_score': 0.9528091164564175}
# Size 8: {'height': 165.14620224450601, 'cup_size': 3.1036758696322773, 'hips': 2.0822739283639864, 'bra_size': 4.897436156811849, 'shoe_size': 12.053727600849694, 'shoe_width': 0.33114399317437837, 'confidence_score': 0.9978475208730213}
# Size 9: {'height': 165.6588, 'cup_size': 2.2333333333333334, 'hips': 2.2600000000000002, 'bra_size': 6.38, 'shoe_size': 12.886666666666667, 'shoe_width': 0.30666666666666664, 'confidence_score': 0.9178669405513519}
# Size 10: {'height': 154.94, 'cup_size': 0.0, 'hips': 1.0, 'bra_size': 11.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 11: {'height': 167.04733333333334, 'cup_size': 4.416666666666666, 'hips': 0.8333333333333333, 'bra_size': 4.2, 'shoe_size': 10.933333333333334, 'shoe_width': 0.4, 'confidence_score': 0.9138595216881304}
# Size 12: {'height': 168.1748515390807, 'cup_size': 3.585107237820806, 'hips': 1.713951438009227, 'bra_size': 5.499621881468615, 'shoe_size': 10.583853048124405, 'shoe_width': 0.32518124672647286, 'confidence_score': 0.9975648920729947}
# Size 13: {'height': 168.148, 'cup_size': 3.4333333333333336, 'hips': 1.7666666666666664, 'bra_size': 5.966666666666667, 'shoe_size': 10.866666666666667, 'shoe_width': 0.6333333333333333, 'confidence_score': 0.8556626896420265}
# Size 15: {'height': 153.6109721614051, 'cup_size': 3.926844272844272, 'hips': 2.0524982966159433, 'bra_size': 6.1844999621470205, 'shoe_size': 10.70057763645999, 'shoe_width': 0.49141797259444325, 'confidence_score': 0.9943617600746697}
# Size 17: {'height': 162.56, 'cup_size': 4.0, 'hips': 1.0, 'bra_size': 6.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 18: {'height': 168.48666666666665, 'cup_size': 5.333333333333333, 'hips': 3.6666666666666665, 'bra_size': 5.0, 'shoe_size': 10.0, 'shoe_width': 1.0, 'confidence_score': 1.0}
# Size 20: {'height': 170.35821547303271, 'cup_size': 4.155968169761273, 'hips': 2.847869142351901, 'bra_size': 6.5848541114058365, 'shoe_size': 10.953143236074272, 'shoe_width': 0.49060565870910705, 'confidence_score': 0.9922872087326693}
# Size 21: {'height': 160.01999999999998, 'cup_size': 5.0, 'hips': 3.0, 'bra_size': 6.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 26: {'height': 168.3294778280543, 'cup_size': 4.03945701357466, 'hips': 3.1660633484162894, 'bra_size': 7.2942081447963805, 'shoe_size': 10.804796380090497, 'shoe_width': 0.4022171945701357, 'confidence_score': 0.9937884237377423}
# Size 27: {'height': 168.48666666666668, 'cup_size': 2.3333333333333335, 'hips': 3.3333333333333335, 'bra_size': 9.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 32: {'height': 169.7228355742297, 'cup_size': 4.715350140056023, 'hips': 3.3036344537815125, 'bra_size': 7.834915966386555, 'shoe_size': 11.248424369747898, 'shoe_width': 0.436281512605042, 'confidence_score': 0.9914166306496088}
# Size 38: {'height': 167.5176181818182, 'cup_size': 5.26987012987013, 'hips': 3.325714285714285, 'bra_size': 8.473766233766234, 'shoe_size': 8.287142857142857, 'shoe_width': 0.8457142857142858, 'confidence_score': 0.9509444122578266}
#
#
# Size chart for 5.0:
# Size 0: {'height': 158.15733333333333, 'cup_size': 1.6666666666666665, 'hips': 2.333333333333333, 'bra_size': 4.2, 'shoe_size': 12.8, 'shoe_width': 0.0, 'confidence_score': 0.9602141788493916}
# Size 1: {'height': 160.42283871538896, 'cup_size': 2.6581139500134574, 'hips': 2.419045415219115, 'bra_size': 4.013838241344854, 'shoe_size': 11.515999839132304, 'shoe_width': 0.34742167754070413, 'confidence_score': 0.9960961149575844}
# Size 4: {'height': 162.57665066775405, 'cup_size': 3.3949976305117864, 'hips': 2.2028869100633544, 'bra_size': 3.0442349149191616, 'shoe_size': 11.002252236677814, 'shoe_width': 0.4562268930335365, 'confidence_score': 0.9997703246478871}
# Size 5: {'height': 165.10000000000002, 'cup_size': 2.5, 'hips': 2.5, 'bra_size': 2.75, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 6: {'height': 169.16400000000002, 'cup_size': 2.0, 'hips': 2.2, 'bra_size': 6.4, 'shoe_size': 13.2, 'shoe_width': 0.4, 'confidence_score': 1.0}
# Size 7: {'height': 161.544, 'cup_size': 3.8, 'hips': 2.1, 'bra_size': 3.1, 'shoe_size': 12.0, 'shoe_width': 0.4, 'confidence_score': 0.9650072893888118}
# Size 8: {'height': 167.79457161293084, 'cup_size': 3.9663700153918633, 'hips': 1.8692809348254507, 'bra_size': 3.6293009977345756, 'shoe_size': 10.175985631993857, 'shoe_width': 0.44330753563175973, 'confidence_score': 0.9997812468403561}
# Size 9: {'height': 163.82999999999998, 'cup_size': 5.5, 'hips': 3.5, 'bra_size': 2.5, 'shoe_size': 11.5, 'shoe_width': 0.5, 'confidence_score': 1.0}
# Size 10: {'height': 163.06800000000004, 'cup_size': 6.5, 'hips': 2.8, 'bra_size': 4.3, 'shoe_size': 12.8, 'shoe_width': 0.0, 'confidence_score': 0.9376390435537676}
# Size 11: {'height': 175.26, 'cup_size': 1.0, 'hips': 0.0, 'bra_size': 4.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 12: {'height': 182.0772370144157, 'cup_size': 6.112854077397721, 'hips': 2.2069593055394683, 'bra_size': 5.45424624720612, 'shoe_size': 8.346340823741158, 'shoe_width': 0.5869546735797965, 'confidence_score': 0.9997767857797998}
# Size 13: {'height': 166.37, 'cup_size': 5.5, 'hips': 1.5, 'bra_size': 5.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 15: {'height': 166.78430104909694, 'cup_size': 5.011720320725986, 'hips': 2.24029195012975, 'bra_size': 5.021895002424871, 'shoe_size': 10.469521648757489, 'shoe_width': 0.49157776547041054, 'confidence_score': 0.9987884833887646}
# Size 20: {'height': 167.6147289865854, 'cup_size': 5.2143085882891285, 'hips': 2.628385920789014, 'bra_size': 5.537671085013622, 'shoe_size': 10.625547510727493, 'shoe_width': 0.46632794252624193, 'confidence_score': 0.9994837280505371}
# Size 26: {'height': 170.22320392985367, 'cup_size': 5.286901830898174, 'hips': 3.272861778787783, 'bra_size': 6.474702896241754, 'shoe_size': 8.423439216833215, 'shoe_width': 0.6176566675711654, 'confidence_score': 0.9991881098483194}
# Size 31: {'height': 167.64, 'cup_size': 5.0, 'hips': 4.0, 'bra_size': 7.0, 'shoe_size': 10.0, 'shoe_width': 1.0, 'confidence_score': 1.0}
# Size 32: {'height': 153.49528441357091, 'cup_size': 5.547350145978053, 'hips': 3.5072151414476993, 'bra_size': 7.716187355280378, 'shoe_size': 11.17926710963455, 'shoe_width': 0.4151904359206684, 'confidence_score': 0.9989806542535986}
# Size 38: {'height': 171.0618210342374, 'cup_size': 5.30395796710196, 'hips': 3.5064852774987445, 'bra_size': 7.89775882094425, 'shoe_size': 10.627002710112171, 'shoe_width': 0.5686282542273564, 'confidence_score': 0.9972764455457803}
#
#
# Size chart for 6.0:
# Size 1: {'height': 157.48000000000002, 'cup_size': 4.0, 'hips': 2.0, 'bra_size': 3.0, 'shoe_size': 9.0, 'shoe_width': 1.0, 'confidence_score': 1.0}
# Size 3: {'height': 167.64, 'cup_size': 3.0, 'hips': 2.0, 'bra_size': 3.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 4: {'height': 163.95700000000002, 'cup_size': 2.7133333333333334, 'hips': 2.5716666666666663, 'bra_size': 4.253333333333333, 'shoe_size': 12.436666666666666, 'shoe_width': 0.2, 'confidence_score': 0.956162514246395}
# Size 5: {'height': 163.82999999999998, 'cup_size': 4.0, 'hips': 2.0, 'bra_size': 3.0, 'shoe_size': 8.0, 'shoe_width': 2.5, 'confidence_score': 1.0}
# Size 8: {'height': 166.14167912087913, 'cup_size': 3.3495238095238093, 'hips': 2.2402930402930403, 'bra_size': 5.009084249084249, 'shoe_size': 13.601904761904763, 'shoe_width': 0.13523809523809524, 'confidence_score': 0.9608454317059362}
# Size 11: {'height': 169.33333333333334, 'cup_size': 2.3333333333333335, 'hips': 1.6666666666666667, 'bra_size': 6.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 12: {'height': 168.15364444444444, 'cup_size': 5.601944444444444, 'hips': 2.3583333333333334, 'bra_size': 4.287222222222222, 'shoe_size': 10.395833333333332, 'shoe_width': 0.2875, 'confidence_score': 0.9689675883160735}
# Size 15: {'height': 167.44244444444445, 'cup_size': 2.488888888888889, 'hips': 2.7444444444444445, 'bra_size': 7.777777777777777, 'shoe_size': 13.933333333333332, 'shoe_width': 0.02222222222222222, 'confidence_score': 0.9286534360195976}
# Size 18: {'height': 165.1, 'cup_size': 5.0, 'hips': 3.0, 'bra_size': 5.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 20: {'height': 164.98267619047618, 'cup_size': 4.8776190476190475, 'hips': 2.500952380952381, 'bra_size': 5.49952380952381, 'shoe_size': 9.671428571428573, 'shoe_width': 0.4376190476190476, 'confidence_score': 0.9456674549372902}
# Size 21: {'height': 170.18, 'cup_size': 4.0, 'hips': 3.0, 'bra_size': 5.0, 'shoe_size': 0.0, 'shoe_width': 3.0, 'confidence_score': 1.0}
# Size 24: {'height': 172.72, 'cup_size': 3.5, 'hips': 4.0, 'bra_size': 6.0, 'shoe_size': 8.0, 'shoe_width': 1.5, 'confidence_score': 1.0}
# Size 26: {'height': 167.0550303030303, 'cup_size': 4.35030303030303, 'hips': 3.1472727272727274, 'bra_size': 7.8199999999999985, 'shoe_size': 11.915151515151514, 'shoe_width': 0.286060606060606, 'confidence_score': 0.943967633577057}
# Size 30: {'height': 165.1, 'cup_size': 5.0, 'hips': 4.0, 'bra_size': 8.0, 'shoe_size': 14.0, 'shoe_width': 0.0, 'confidence_score': 1.0}
# Size 32: {'height': 167.513, 'cup_size': 5.0, 'hips': 3.55, 'bra_size': 7.85, 'shoe_size': 11.15, 'shoe_width': 0.15, 'confidence_score': 0.8794121186891262}
# Size 38: {'height': 168.148, 'cup_size': 5.6, 'hips': 3.6, 'bra_size': 8.6, 'shoe_size': 8.4, 'shoe_width': 1.4, 'confidence_score': 1.0}
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\3101688938.py:79: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_adjusted = category_groups.apply(adjust_sizes_based_on_fit)

# %%
for category, chart in size_charts.items():
    # Create an empty DataFrame
    df = pd.DataFrame(columns=['size', 'height', 'cup_size', 'hips', 'bra_size', 'shoe_size', 'shoe_width', 'confidence_score'])
    
    for size, measurements in chart.items():
        # Append measurements to the DataFrame
        df = df.append({
            'size': size,
            'height': measurements['height'],
            'cup_size': measurements['cup_size'],
            'hips': measurements['hips'],
            'bra_size': measurements['bra_size'],
            'shoe_size': measurements['shoe_size'],
            'shoe_width': measurements['shoe_width'],
            'confidence_score': measurements['confidence_score']
        }, ignore_index=True)
    
    # Save the DataFrame as a CSV file
    df.to_csv(f'size_chart__{category}.csv', index=False)

    print(f"\nSaved size chart for {category} as {category}_size_chart.csv")
# Out:
# Saved size chart for 0.0 as 0.0_size_chart.csv
#
# Saved size chart for 1.0 as 1.0_size_chart.csv
#
# Saved size chart for 2.0 as 2.0_size_chart.csv
#
# Saved size chart for 3.0 as 3.0_size_chart.csv
#
# Saved size chart for 4.0 as 4.0_size_chart.csv
#
# Saved size chart for 5.0 as 5.0_size_chart.csv
#
# Saved size chart for 6.0 as 6.0_size_chart.csv
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\aasli\AppData\Local\Temp\ipykernel_18680\4238257021.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
